# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from collections import Counter
from num2words import num2words


import nltk
import os
import string
import numpy as np
import copy 
import pickle
import re
import math

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

data = pd.read_csv("C:\Projects_by_month\MLproject\data\ISW_csv\\1_all_isw_reports.csv")
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\P'
# <>:22: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\illya\AppData\Local\Temp\ipykernel_13020\3634435603.py:22: SyntaxWarning: invalid escape sequence '\P'
#   data = pd.read_csv("C:\Projects_by_month\MLproject\data\ISW_csv\\1_all_isw_reports.csv")

# %%
data.head()
# Out:
#    Unnamed: 0        date   short_url  \
# 0           0  2022-02-24  february24
# 1           1  2022-02-25  february25
# 2           2  2022-02-26  february26
# 3           3  2022-02-27  february27
# 4           4  2022-02-28  february28
#
#                                                title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russia-Ukraine Warning Update: Russian Offensi...
# 4  Russian Offensive Campaign Assessment, Februar...
#
#                                           text_title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russia-Ukraine Warning Update: Russian Offensi...
# 4  Russian Offensive Campaign Assessment, Februar...
#
#                                             full_url  \
# 0  /backgrounder/russia-ukraine-warning-update-in...
# 1  /backgrounder/russia-ukraine-warning-update-ru...
# 2  /backgrounder/russia-ukraine-warning-update-ru...
# 3  /backgrounder/russia-ukraine-warning-update-ru...
# 4  /backgrounder/russian-offensive-campaign-asses...
#
#                                            main_html  \
# 0  <div class="field field-name-body field-type-t...
# 1  <div class="field field-name-body field-type-t...
# 2  <div class="field field-name-body field-type-t...
# 3  <div class="field field-name-body field-type-t...
# 4  <div class="field field-name-body field-type-t...
#
#                                         main_html_v6
# 0  Mason Clark, George Barros, and Kateryna Stepa...
# 1  February 25, 3:00 pm ESTRussian forces entered...
# 2  February 26, 3pm ESTRussian forces’ main axes ...
# 3  Mason Clark, George Barros, and Kateryna Stepa...
# 4  Mason Clark, George Barros, and Kateryna Stepa...

# %% [markdown]
# ### Prepare functions

# %%
def remove_one_letter_word(data):
    words = word_tokenize(str(data))
    
    new_text = ""
    for w in words:
        if (len(w) > 1):
            new_text = new_text + " " + w
            
    return new_text

# %%
#remove_one_letter_word(data['main_html_v6'][0])
# Out:
# ' Mason Clark George Barros and Kateryna StepanenkoFebruary 24 3:00 pm ESTRussian President Vladimir Putin began large-scale invasion of Ukraine on February 24 likely aimed at full regime change and the occupation of Ukraine.His claimed objective to demilitarize and de-nazify Ukraine is transparent cover for an unprovoked war of aggression to occupy neighboring state Putin and Kremlin media continue to deny that the Russian invasion is war instead describing it as special military operation.Putin messaging is likely aimed at domestic Russian audience which the Kremlin has not fully prepared for the costs of war against Ukraine Russian officials and state media have been denying and mocking Western warnings of the impending Russian invasion for months and as recently as February 23.Russian forces remain much larger and more capable than Ukraine conventional military Russia will likely defeat Ukrainian regular military forces and secure their territorial objectives at some point in the coming days or weeks if Putin is determined to do so and willing to pay the cost in blood and treasure.Key TakeawaysUkrainian forces are successfully slowing Russian offensives on all axes of advance other than Russian breakout from the Crimean Peninsula Russian failure to ground the Ukrainian air force or cripple Ukrainian command and control is likely enabling these initial Ukrainian successes.Ukrainian forces are contesting the Hostomel military airport 20 km northwest of Kyiv as of 9:30 pm local time.Russian VDV Airborne troops landed at Hostomel and have also failed to capture the Boryspil airport southeast of Kyiv Ukraine contestation of the airport deprives Russian forces of any location to airlift forces onto Kyiv western flank overnight.Russian forces are rapidly advancing north from Crimea securing Kherson city Their deepest penetration to date is about 60 kilometers.Russian forces are advancing on Kyiv from Belarus on both sides of the Dnipro River Russian forces secured the Chernobyl Exclusion Zone on the west bank at 7:30 pm local time but Ukrainian forces have slowed Russian advances east of the Dnipro at Chernihiv.Russian forces likely seek to cut off Ukrainian troops on the line of contact in Donbas using an envelopment behind the Ukrainian front lines through Luhansk Oblast Russian frontal assaults have taken little territory in Donetsk and Luhansk at this time.Russian military operations began with short and incomplete air campaign on February 24 around 4:00 am local time targeting Ukrainian air defenses supply depots and airfields across unoccupied Ukraine However portions of the Ukrainian Air Force remain operational and Ukrainian command and control appears intact.US defense officials estimate initial strikes comprised over 100 missiles including mix of short and medium-range ballistic missiles cruise missiles and sea-launched missiles.An estimated 75 Russian bombers participated in the attack.Russia did not successfully ground the Ukrainian air force or cripple the Ukrainian armed forces enabling several Ukrainian successes on February 24 ISW incorrectly forecasted that any Russian offensive would begin with concentrated air and missile campaign to cripple Ukrainian command and control and infrastructure.The Russian failure to comprehensively strike key Ukrainian assets is surprising break from expected Russian operations and has likely enabled stiffer Ukrainian defense The Ukrainian military has shot down seven Russian aircraft and seven helicopters as of 8:00 pm local time February 24.Russia has not demonstrated its full air and missile capabilities and will likely conduct further waves of strikes in the coming days aimed at degrading Ukraine command and control and ability to redeploy forces.Ukrainian forces are currently contesting the Hostomel military airport 20 km northwest of Kyiv against Russian VDV airborne troops likely from the 31st Guards Air Assault Brigade as of 9:30 pm local time after several unsuccessful cou ...

# %%
def convert_lower_case(data):
    return np.char.lower(data)

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'in', 'mightn', 'd', 'between', "needn't", 'now', 'while', 'our', 'again', 'after', 'most', 'only', "we'd", 'the', "they'd", 'yourselves', "isn't", "i'm", 'all', 've', 'was', 'doesn', "he'd", 'both', 'a', 'its', "it's", 'can', 'other', 'her', 'shouldn', 'some', 'up', "they'll", "won't", 'against', 'then', 'y', "hasn't", "weren't", 'had', 'it', 'during', "they're", 'she', 'whom', 'before', 're', "you'd", 'yourself', 'just', 'any', 'but', "doesn't", 'few', 'out', 'to', "i'll", 't', 'we', 'will', 'wasn', "aren't", 'down', 'ain', 'very', "he's", 'his', 'once', 'were', 'above', 'at', 'because', "haven't", 'until', 'by', 'wouldn', 'o', 'this', 'be', 'with', 'mustn', 'shan', 'over', "that'll", 'don', 'herself', 'and', 'ma', 'my', 'for', "you'll", 'same', "don't", 'own', 'you', "she'd", "wasn't", 'i', "we'll", 'have', 'below', 'hadn', 'isn', 'ourselves', "we've", 'your', 'is', 'having', 'more', "i'd", 'should', 's', 'that', 'themselves', 'doing', "shan't", 'did', 'him', 'ours', 'of', 'won', 'they', 'being', 'll', 'their', 'there', 'into', 'so', 'yours', 'who', 'didn', 'about', 'himself', "hadn't", 'couldn', "you've", 'if', "couldn't", 'not', 'those', 'an', 'from', 'or', 'why', "wouldn't", 'nor', 'each', 'needn', "she's", 'theirs', "they've", 'what', 'no', "it'd", 'through', "i've", 'aren', 'does', 'm', 'myself', 'hers', 'hasn', 'off', 'such', 'itself', 'these', "shouldn't", 'me', 'haven', 'which', 'on', 'them', "mustn't", "didn't", 'too', 'as', 'when', 'are', 'under', 'has', "should've", "it'll", 'how', 'been', 'here', "she'll", 'where', "mightn't", "he'll", 'am', "we're", 'weren', 'than', "you're", 'further', 'do', 'he'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\illya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stop_words(data):
    stop_words = set(stopwords.words('english'))
    stop_stop_words = {"no","not"}
    
    stop_words = stop_words - stop_stop_words
    
    words = word_tokenize(str(data))
    
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
            
    return new_text

# %%
#remove_stop_words(data['main_html_v6'][0])
# Out:
# ' Mason Clark George Barros Kateryna StepanenkoFebruary 24 3:00 pm ESTRussian President Vladimir Putin began large-scale invasion Ukraine February 24 likely aimed full regime change occupation Ukraine.His claimed objective demilitarize de-nazify Ukraine transparent cover unprovoked war aggression occupy neighboring state Putin Kremlin media continue deny Russian invasion war instead describing special military operation.Putin messaging likely aimed domestic Russian audience Kremlin not fully prepared costs war Ukraine Russian officials state media denying mocking Western warnings impending Russian invasion months recently February 23.Russian forces remain much larger capable Ukraine conventional military Russia likely defeat Ukrainian regular military forces secure territorial objectives point coming days weeks Putin determined willing pay cost blood treasure.Key TakeawaysUkrainian forces successfully slowing Russian offensives axes advance Russian breakout Crimean Peninsula Russian failure ground Ukrainian air force cripple Ukrainian command control likely enabling initial Ukrainian successes.Ukrainian forces contesting Hostomel military airport 20 km northwest Kyiv 9:30 pm local time.Russian VDV Airborne troops landed Hostomel also failed capture Boryspil airport southeast Kyiv Ukraine contestation airport deprives Russian forces location airlift forces onto Kyiv western flank overnight.Russian forces rapidly advancing north Crimea securing Kherson city Their deepest penetration date 60 kilometers.Russian forces advancing Kyiv Belarus sides Dnipro River Russian forces secured Chernobyl Exclusion Zone west bank 7:30 pm local time Ukrainian forces slowed Russian advances east Dnipro Chernihiv.Russian forces likely seek cut Ukrainian troops line contact Donbas using envelopment behind Ukrainian front lines Luhansk Oblast Russian frontal assaults taken little territory Donetsk Luhansk time.Russian military operations began short incomplete air campaign February 24 around 4:00 local time targeting Ukrainian air defenses supply depots airfields across unoccupied Ukraine However portions Ukrainian Air Force remain operational Ukrainian command control appears intact.US defense officials estimate initial strikes comprised 100 missiles including mix short medium-range ballistic missiles cruise missiles sea-launched missiles.An estimated 75 Russian bombers participated attack.Russia not successfully ground Ukrainian air force cripple Ukrainian armed forces enabling several Ukrainian successes February 24 ISW incorrectly forecasted Russian offensive would begin concentrated air missile campaign cripple Ukrainian command control infrastructure.The Russian failure comprehensively strike key Ukrainian assets surprising break expected Russian operations likely enabled stiffer Ukrainian defense The Ukrainian military shot seven Russian aircraft seven helicopters 8:00 pm local time February 24.Russia not demonstrated full air missile capabilities likely conduct waves strikes coming days aimed degrading Ukraine command control ability redeploy forces.Ukrainian forces currently contesting Hostomel military airport 20 km northwest Kyiv Russian VDV airborne troops likely 31st Guards Air Assault Brigade 9:30 pm local time several unsuccessful counterattacks earlier day.Russian airborne forces additionally unable secure Boryspil airport Kyiv primary international airport southeast Kyiv.Ukraine contestation airport prevents Russia airlifting reinforcements isolate Kyiv western Ukraine feared earlier day.Russian ground forces advancing four primary axes discussed turn Belarus/Kyiv Kharkiv Donbas andCrimea-Kherson.1 Belarus/Kyiv axis Russian forces Belarus advancing Kyiv along sides Dnipro River likely seeking isolate Kyiv Russian forces made greater progress west Dnipro successfully securing Chernobyl exclusion zone.Ukrainian forces reported halting Russia offensive elements 36th Combined Arms Army Kyiv Oblast Belarus Chernihiv roughly 120 km northe ...

# %%
def remove_punctuations(data):
    symbols = " !()-[]{};:'\,<>./?@#$%^&*_~ '"""  
    
    for i in range(len(symbols)):
        data = np.char.replace(data,symbols[i]," ")
        data = np.char.replace(data,"  "," ")
    
    data = np.char.replace(data,",", " ")
    
    return data
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\,'
# <>:2: SyntaxWarning: invalid escape sequence '\,'
# C:\Users\illya\AppData\Local\Temp\ipykernel_16872\1595285326.py:2: SyntaxWarning: invalid escape sequence '\,'
#   symbols = " !()-[]{};:'\,<>./?@#$%^&*_~ '"""

# %%
#remove_punctuations(data['main_html_v6'][0])
# Out:
# array('Mason Clark George Barros and Kateryna StepanenkoFebruary 24 3 00 pm ESTRussian President Vladimir Putin began a large scale invasion of Ukraine on February 24 likely aimed at full regime change and the occupation of Ukraine His claimed objective to “demilitarize” and “de nazify” Ukraine is a transparent cover for an unprovoked war of aggression to occupy a neighboring state Putin and Kremlin media continue to deny that the Russian invasion is a war instead describing it as a special military operation Putin’s messaging is likely aimed at a domestic Russian audience which the Kremlin has not fully prepared for the costs of a war against Ukraine Russian officials and state media have been denying and mocking Western warnings of the impending Russian invasion for months and as recently as February 23 Russian forces remain much larger and more capable than Ukraine’s conventional military Russia will likely defeat Ukrainian regular military forces and secure their territorial objectives at some point in the coming days or weeks if Putin is determined to do so and willing to pay the cost in blood and treasure Key TakeawaysUkrainian forces are successfully slowing Russian offensives on all axes of advance other than a Russian breakout from the Crimean Peninsula Russian failure to ground the Ukrainian air force or cripple Ukrainian command and control is likely enabling these initial Ukrainian successes Ukrainian forces are contesting the Hostomel military airport 20 km northwest of Kyiv as of 9 30 pm local time Russian VDV Airborne troops landed at Hostomel and have also failed to capture the Boryspil airport southeast of Kyiv Ukraine’s contestation of the airport deprives Russian forces of any location to airlift forces onto Kyiv’s western flank overnight Russian forces are rapidly advancing north from Crimea securing Kherson city Their deepest penetration to date is about 60 kilometers Russian forces are advancing on Kyiv from Belarus on both sides of the Dnipro River Russian forces secured the Chernobyl Exclusion Zone on the west bank at 7 30 pm local time but Ukrainian forces have slowed Russian advances east of the Dnipro at Chernihiv Russian forces likely seek to cut off Ukrainian troops on the line of contact in Donbas using an envelopment behind the Ukrainian front lines through Luhansk Oblast Russian frontal assaults have taken little territory in Donetsk and Luhansk at this time Russian military operations began with a short and incomplete air campaign on February 24 around 4 00 am local time targeting Ukrainian air defenses supply depots and airfields across unoccupied Ukraine However portions of the Ukrainian Air Force remain operational and Ukrainian command and control appears intact US defense officials estimate initial strikes comprised over 100 missiles including a mix of short and medium range ballistic missiles cruise missiles and sea launched missiles An estimated 75 Russian bombers participated in the attack Russia did not successfully ground the Ukrainian air force or cripple the Ukrainian armed forces enabling several Ukrainian successes on February 24 ISW incorrectly forecasted that any Russian offensive would begin with a concentrated air and missile campaign to cripple Ukrainian command and control and infrastructure The Russian failure to comprehensively strike key Ukrainian assets is a surprising break from expected Russian operations and has likely enabled stiffer Ukrainian defense The Ukrainian military has shot down seven Russian aircraft and seven helicopters as of 8 00 pm local time February 24 Russia has not demonstrated its full air and missile capabilities and will likely conduct further waves of strikes in the coming days aimed at degrading Ukraine’s command and control and ability to redeploy forces Ukrainian forces are currently contesting the Hostomel military airport 20 km northwest of Kyiv against Russian VDV airborne troops likely from the 31st Guards Air Assault Brigade as of 9 30 p ...
#       dtype='<U9623')

# %%
def stemming(data):
    stemmer = PorterStemmer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
        
    return new_text

def lemmatizing(data):
    lemmatizer = WordNetLemmatizer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + lemmatizer.lemmatize(w)
               
    return new_text

# %%
def convert_numbers(data):
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        if w.isdigit():
            if int(w) < 1000000000:
                w = num2words(w)
            else:
                w = " "
        new_text = new_text + " " + w
            
    new_text = np.char.replace(new_text,"-"," ")
        
    return new_text

# %%
#convert_numbers(data['main_html_v6'][0])
# Out:
# array(' Mason Clark , George Barros , and Kateryna StepanenkoFebruary twenty four , 3:00 pm ESTRussian President Vladimir Putin began a large scale invasion of Ukraine on February twenty four likely aimed at full regime change and the occupation of Ukraine.His claimed objective to “ demilitarize ” and “ de nazify ” Ukraine is a transparent cover for an unprovoked war of aggression to occupy a neighboring state . Putin and Kremlin media continue to deny that the Russian invasion is a war , instead describing it as a special military operation.Putin ’ s messaging is likely aimed at a domestic Russian audience , which the Kremlin has not fully prepared for the costs of a war against Ukraine . Russian officials and state media have been denying and mocking Western warnings of the impending Russian invasion for months and as recently as February 23.Russian forces remain much larger and more capable than Ukraine ’ s conventional military . Russia will likely defeat Ukrainian regular military forces and secure their territorial objectives at some point in the coming days or weeks if Putin is determined to do so and willing to pay the cost in blood and treasure.Key TakeawaysUkrainian forces are successfully slowing Russian offensives on all axes of advance other than a Russian breakout from the Crimean Peninsula . Russian failure to ground the Ukrainian air force or cripple Ukrainian command and control is likely enabling these initial Ukrainian successes.Ukrainian forces are contesting the Hostomel military airport , twenty km northwest of Kyiv , as of 9:30 pm local time.Russian VDV ( Airborne ) troops landed at Hostomel and have also failed to capture the Boryspil airport southeast of Kyiv . Ukraine ’ s contestation of the airport deprives Russian forces of any location to airlift forces onto Kyiv ’ s western flank overnight.Russian forces are rapidly advancing north from Crimea , securing Kherson city . Their deepest penetration to date is about sixty kilometers.Russian forces are advancing on Kyiv from Belarus on both sides of the Dnipro River . Russian forces secured the Chernobyl Exclusion Zone ( on the west bank ) at 7:30 pm local time , but Ukrainian forces have slowed Russian advances east of the Dnipro at Chernihiv.Russian forces likely seek to cut off Ukrainian troops on the line of contact in Donbas using an envelopment behind the Ukrainian front lines through Luhansk Oblast . Russian frontal assaults have taken little territory in Donetsk and Luhansk at this time.Russian military operations began with a short and incomplete air campaign on February twenty four around 4:00 am local time targeting Ukrainian air defenses , supply depots , and airfields across unoccupied Ukraine . However , portions of the Ukrainian Air Force remain operational and Ukrainian command and control appears intact.US defense officials estimate initial strikes comprised over one hundred missiles including a mix of short and medium range ballistic missiles , cruise missiles , and sea launched missiles.An estimated seventy five Russian bombers participated in the attack.Russia did not successfully ground the Ukrainian air force or cripple the Ukrainian armed forces , enabling several Ukrainian successes on February twenty four . ISW incorrectly forecasted that any Russian offensive would begin with a concentrated air and missile campaign to cripple Ukrainian command and control and infrastructure.The Russian failure to comprehensively strike key Ukrainian assets is a surprising break from expected Russian operations and has likely enabled stiffer Ukrainian defense . The Ukrainian military has shot down seven Russian aircraft and seven helicopters as of 8:00 pm local time , February 24.Russia has not demonstrated its full air and missile capabilities and will likely conduct further waves of strikes in the coming days aimed at degrading Ukraine ’ s command and control and ability to redeploy forces.Ukrainian forces are currently contesting the Hostomel ...
#       dtype='<U9924')

# %%
def remove_url_from_string(data):
    words = word_tokenize(str(data))
    new_text = ""

    
    for w in words:
        w = re.sub(r'https?:\/\/.*[\r\n]*',"",str(w),flags=re.MULTILINE)
        w = re.sub(r'http?:\/\/.*[\r\n]*',"",str(w),flags=re.MULTILINE)
        
        new_text = new_text + " " + w
        
    return new_text

# %%
def preprocess(data, word_root_algo='lemm'):
    
    data = remove_one_letter_word(data)
    data = convert_lower_case(data)
    data = remove_stop_words(data)
    data = stemming(data)
    data = remove_punctuations(data)
    data = convert_numbers(data)
    data = remove_url_from_string(data)
    
    if word_root_algo =='lemm':
        data = lemmatizing(data)
    else: 
        data = stemming(data)
        
    
    data = remove_punctuations(data)
    data = remove_stop_words(data)
    
    return data

# %%
data['report_text_lemm'] = data['main_html_v6'].apply(lambda x: preprocess(x,"lemm"))

# %%
data['report_text_stemm'] = data['main_html_v6'].apply(lambda x: preprocess(x,"stemm"))

# %%
data.head()
# Out:
#    Unnamed: 0        date   short_url  \
# 0           0  2022-02-24  february24
# 1           1  2022-02-25  february25
# 2           2  2022-02-26  february26
# 3           3  2022-02-27  february27
# 4           4  2022-02-28  february28
#
#                                                title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russia-Ukraine Warning Update: Russian Offensi...
# 4  Russian Offensive Campaign Assessment, Februar...
#
#                                           text_title  \
# 0  Russia-Ukraine Warning Update: Initial Russian...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russia-Ukraine Warning Update: Russian Offensi...
# 4  Russian Offensive Campaign Assessment, Februar...
#
#                                             full_url  \
# 0  /backgrounder/russia-ukraine-warning-update-in...
# 1  /backgrounder/russia-ukraine-warning-update-ru...
# 2  /backgrounder/russia-ukraine-warning-update-ru...
# 3  /backgrounder/russia-ukraine-warning-update-ru...
# 4  /backgrounder/russian-offensive-campaign-asses...
#
#                                            main_html  \
# 0  <div class="field field-name-body field-type-t...
# 1  <div class="field field-name-body field-type-t...
# 2  <div class="field field-name-body field-type-t...
# 3  <div class="field field-name-body field-type-t...
# 4  <div class="field field-name-body field-type-t...
#
#                                         main_html_v6  \
# 0  Mason Clark, George Barros, and Kateryna Stepa...
# 1  February 25, 3:00 pm ESTRussian forces entered...
# 2  February 26, 3pm ESTRussian forces’ main axes ...
# 3  Mason Clark, George Barros, and Kateryna Stepa...
# 4  Mason Clark, George Barros, and Kateryna Stepa...
#
#                                     report_text_lemm  \
# 0   mason clark georg barro kateryna stepanenkofe...
# 1   februari twenty five three zero pm estrussian...
# 2   februari twenty six 3pm estrussian forc main ...
# 3   mason clark georg barro kateryna stepanenkofe...
# 4   mason clark georg barro kateryna stepanenkofe...
#
#                                    report_text_stemm
# 0   mason clark georg barro kateryna stepanenkofe...
# 1   februari twenti five three zero pm estrussian...
# 2   februari twenti six 3pm estrussian forc main ...
# 3   mason clark georg barro kateryna stepanenkofe...
# 4   mason clark georg barro kateryna stepanenkofe...

# %%
data['report_text_lemm'][0]
# Out:
# ' mason clark georg barro kateryna stepanenkofebruari twenty four three zero pm estrussian presid vladimir putin began large scal invas ukrain februari twenty four like aim full regim chang occup ukraine hi claim object demilitar de nazifi ukrain transpar cover unprovok war aggress occupi neighbor state putin kremlin medium continu deni russian invas war instead describ special militari operation putin messag like aim domest russian audienc kremlin not fulli prepar cost war ukrain russian offici state medium deni mock western warn impend russian invas month recent februari twenty three russian forc remain much larger capabl ukrain convent militari russia like defeat ukrainian regular militari forc secur territori object point come day week putin determin pay cost blood treasure key takeawaysukrainian forc success slow russian offens axe advanc russian breakout crimean peninsula russian failur ground ukrainian air forc crippl ukrainian command control like enabl initi ukrainian success ukrainian forc contest hostomel militari airport twenty km northwest kyiv nine thirty pm local time russian vdv airborn troop land hostomel also fail captur boryspil airport southeast kyiv ukrain contest airport depriv russian forc locat airlift forc onto kyiv western flank overnight russian forc rapidli advanc north crimea secur kherson citi deepest penetr date sixty kilometer russian forc advanc kyiv belaru side dnipro river russian forc secur chernobyl exclus zone west bank seven thirty pm local time ukrainian forc slow russian advanc east dnipro chernihiv russian forc like seek cut ukrainian troop line contact donba use envelop behind ukrainian front line luhansk oblast russian frontal assault taken littl territori donetsk luhansk time russian militari oper began short incomplet air campaign februari twenty four around four zero local time target ukrainian air defens suppli depot airfield across unoccupi ukrain howev portion ukrainian air forc remain oper ukrainian command control appear intact defens offici estim initi strike compris one hundred missil includ mix short medium rang ballist missil cruis missil sea launch missile estim seventy five russian bomber particip attack russia not success ground ukrainian air forc crippl ukrainian arm forc enabl sever ukrainian success februari twenty four isw incorrectli forecast russian offens would begin concentr air missil campaign crippl ukrainian command control infrastructure th russian failur comprehens strike key ukrainian asset surpris break expect russian oper like enabl stiffer ukrainian defens ukrainian militari shot seven russian aircraft seven helicopt eight zero pm local time februari twenty four russia not demonstr full air missil capabl like conduct wave strike come day aim degrad ukrain command control abil redeploy force ukrainian forc current contest hostomel militari airport twenty km northwest kyiv russian vdv airborn troop like 31st guard air assault brigad nine thirty pm local time sever unsuccess counterattack earlier day russian airborn forc addit unabl secur boryspil airport kyiv primari intern airport southeast kyiv ukrain contest airport prevent russia airlift reinforc isol kyiv western ukrain fear earlier day russian ground forc advanc four primari axe discus turn belarus kyiv kharkiv donba andcrimea kherson one belarus kyiv axi russian forc belaru advanc kyiv along side dnipro river like seek isol kyiv russian forc made greater progress west dnipro success secur chernobyl exclus zone ukrainian forc report halt russia offens element 36th combin arm armi kyiv oblast belaru chernihiv roughli one hundred twenty km northeast kyiv includ captur entir reconnaiss platoon russian 74th motor rifl brigade russian forc secur chernobyl exclus zone seven thirty pm local time russian forc like intend cut kyiv western ukrain drive western bank dnipro river failur russian airborn forc secur hostomel airport imped envelopment no belarusian forc confirm particip oper ukrain time belarusian ...

# %%
docs = data['report_text_lemm'].tolist()

# %%
data.to_csv("C:\Projects_by_month\MLproject\data\ISW_csv\\2_isw_preprocessed_before_vectosing.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\illya\AppData\Local\Temp\ipykernel_16872\843594564.py:1: SyntaxWarning: invalid escape sequence '\P'
#   data.to_csv("C:\Projects_by_month\MLproject\data\ISW_csv\\2_isw_preprocessed_before_vectosing.csv")

# %% [markdown]
# ## CountVerctorizer

# %%
cv = CountVectorizer(max_df=0.98,min_df=2)
word_count_vector = cv.fit_transform(docs)

word_count_vector.shape
# Out:
# (1083, 15304)

# %%
data.head(15)
# Out:
#     Unnamed: 0        date   short_url  \
# 0            0  2022-02-24  february24
# 1            1  2022-02-25  february25
# 2            2  2022-02-26  february26
# 3            3  2022-02-27  february27
# 4            4  2022-02-28  february28
# 5            5  2022-03-01     march01
# 6            6  2022-03-02     march02
# 7            7  2022-03-03     march03
# 8            8  2022-03-04     march04
# 9            9  2022-03-05     march05
# 10          10  2022-03-06     march06
# 11          11  2022-03-07     march07
# 12          12  2022-03-08     march08
# 13          13  2022-03-09     march09
# 14          14  2022-03-10     march10
#
#                                                 title  \
# 0   Russia-Ukraine Warning Update: Initial Russian...
# 1   Russia-Ukraine Warning Update: Russian Offensi...
# 2   Russia-Ukraine Warning Update: Russian Offensi...
# 3   Russia-Ukraine Warning Update: Russian Offensi...
# 4   Russian Offensive Campaign Assessment, Februar...
# 5   Russian Offensive Campaign Assessment, March 1...
# 6   Russian Offensive Campaign Assessment, March 2...
# 7   Russian Offensive Campaign Assessment, March 3...
# 8   Russian Offensive Campaign Assessment, March 4...
# 9   Russian Offensive Campaign Assessment, March 5...
# 10  Russian Offensive Campaign Assessment, March 6...
# 11  Russian Offensive Campaign Assessment, March 7...
# 12  Russian Offensive Campaign Assessment, March 8...
# 13  Russian Offensive Campaign Assessment, March 9...
# 14  Russian Offensive Campaign Assessment, March 1...
#
#                                            text_title  \
# 0   Russia-Ukraine Warning Update: Initial Russian...
# 1   Russia-Ukraine Warning Update: Russian Offensi...
# 2   Russia-Ukraine Warning Update: Russian Offensi...
# 3   Russia-Ukraine Warning Update: Russian Offensi...
# 4   Russian Offensive Campaign Assessment, Februar...
# 5      Russian Offensive Campaign Assessment, March 1
# 6      Russian Offensive Campaign Assessment, March 2
# 7      Russian Offensive Campaign Assessment, March 3
# 8      Russian Offensive Campaign Assessment, March 4
# 9      Russian Offensive Campaign Assessment, March 5
# 10     Russian Offensive Campaign Assessment, March 6
# 11     Russian Offensive Campaign Assessment, March 7
# 12     Russian Offensive Campaign Assessment, March 8
# 13     Russian Offensive Campaign Assessment, March 9
# 14    Russian Offensive Campaign Assessment, March 10
#
#                                              full_url  \
# 0   /backgrounder/russia-ukraine-warning-update-in...
# 1   /backgrounder/russia-ukraine-warning-update-ru...
# 2   /backgrounder/russia-ukraine-warning-update-ru...
# 3   /backgrounder/russia-ukraine-warning-update-ru...
# 4   /backgrounder/russian-offensive-campaign-asses...
# 5   /backgrounder/russian-offensive-campaign-asses...
# 6   /backgrounder/russian-offensive-campaign-asses...
# 7   /backgrounder/russian-offensive-campaign-asses...
# 8   /backgrounder/russian-offensive-campaign-asses...
# 9   /backgrounder/russian-offensive-campaign-asses...
# 10  /backgrounder/russian-offensive-campaign-asses...
# 11  /backgrounder/russian-offensive-campaign-asses...
# 12  /backgrounder/russian-offensive-campaign-asses...
# 13  /backgrounder/russian-offensive-campaign-asses...
# 14  /backgrounder/russian-offensive-campaign-asses...
#
#                                             main_html  \
# 0   <div class="field field-name-body field-type-t...
# 1   <div class="field field-name-body field-type-t...
# 2   <div class="field field-name-body field-type-t...
# 3   <div class="field field-name-body field-type-t...
# 4   <div class="field field-name-body field-type-t...
# 5   <div class="field field-name-body field-type-t...
# 6   <div class="field field-name-body field-type-t...
# 7   <div class="field field-name-body field-type-t...
# 8   <div class="field field-name-body field-type-t...
# 9   <div class="field field-name-body field-type-t...
# 10  <div class="field field-name-body field-type-t...
# 11  <div class="field field-name-body field-type-t...
# 12  <div class="field field-name-body field-type-t...
# 13  <div class="field field-name-body field-type-t...
# 14  <div class="field field-name-body field-type-t...
#
#                                          main_html_v6  \
# 0   Mason Clark, George Barros, and Kateryna Stepa...
# 1   February 25, 3:00 pm ESTRussian forces entered...
# 2   February 26, 3pm ESTRussian forces’ main axes ...
# 3   Mason Clark, George Barros, and Kateryna Stepa...
# 4   Mason Clark, George Barros, and Kateryna Stepa...
# 5   Frederick W. Kagan, George Barros, and Kateryn...
# 6   Mason Clark, George Barros, and Kateryna Stepa...
# 7   Mason Clark, George Barros, and Kateryna Stepa...
# 8   Fredrick W. Kagan, George Barros, and Kateryna...
# 9   Fredrick W. Kagan, George Barros, and Kateryna...
# 10  Fredrick W. Kagan, George Barros, and Kateryna...
# 11  Fredrick W. Kagan, George Barros, and Kateryna...
# 12  Fredrick W. Kagan, George Barros, and Kateryna...
# 13  Fredrick W. Kagan, George Barros, and Kateryna...
# 14  Mason Clark, George Barros, and Kateryna Stepa...
#
#                                      report_text_lemm  \
# 0    mason clark georg barro kateryna stepanenkofe...
# 1    februari twenty five three zero pm estrussian...
# 2    februari twenty six 3pm estrussian forc main ...
# 3    mason clark georg barro kateryna stepanenkofe...
# 4    mason clark georg barro kateryna stepanenkofe...
# 5    frederick kagan georg barro kateryna stepanen...
# 6    mason clark georg barro kateryna stepanenkoma...
# 7    mason clark georg barro kateryna stepanenkoma...
# 8    fredrick kagan georg barro kateryna stepanenk...
# 9    fredrick kagan georg barro kateryna stepanenk...
# 10   fredrick kagan georg barro kateryna stepanenk...
# 11   fredrick kagan georg barro kateryna stepanenk...
# 12   fredrick kagan georg barro kateryna stepanenk...
# 13   fredrick kagan georg barro kateryna stepanenk...
# 14   mason clark georg barro kateryna stepanenkoma...
#
#                                     report_text_stemm
# 0    mason clark georg barro kateryna stepanenkofe...
# 1    februari twenti five three zero pm estrussian...
# 2    februari twenti six 3pm estrussian forc main ...
# 3    mason clark georg barro kateryna stepanenkofe...
# 4    mason clark georg barro kateryna stepanenkofe...
# 5    frederick kagan georg barro kateryna stepanen...
# 6    mason clark georg barro kateryna stepanenkoma...
# 7    mason clark georg barro kateryna stepanenkoma...
# 8    fredrick kagan georg barro kateryna stepanenk...
# 9    fredrick kagan georg barro kateryna stepanenk...
# 10   fredrick kagan georg barro kateryna stepanenk...
# 11   fredrick kagan georg barro kateryna stepanenk...
# 12   fredrick kagan georg barro kateryna stepanenk...
# 13   fredrick kagan georg barro kateryna stepanenk...
# 14   mason clark georg barro kateryna stepanenkoma...

# %%
word_count_vector
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 883116 stored elements and shape (1083, 15304)>

# %%
with open(r"C:\\Projects_by_month\\MLproject\\models\\count_vectorizer_v1.pkl", "wb") as handle:
    pickle.dump(cv, handle)

# %% [markdown]
# ### TF-IDF

# %%
tfidf_transformer = TfidfTransformer(smooth_idf = True, use_idf = True)
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer()

# %%
with open("C:\\Projects_by_month\\MLproject\\models\\tfidf_transformer.pkl","wb") as handle:
    pickle.dump(tfidf_transformer, handle)

# %%
df_idf = pd.DataFrame(tfidf_transformer.idf_, index = cv.get_feature_names_out(),columns=["idf_weights"])
df_idf.sort_values(by=['idf_weights'])
# Out:
#            idf_weights
# two           1.020504
# one           1.021446
# twenty        1.021446
# convent       1.021446
# axi           1.021446
# ...                ...
# род           6.889801
# отдельный     6.889801
# ополчение     6.889801
# народное      6.889801
# коридор       6.889801
#
# [15304 rows x 1 columns]

# %%
tf_idf_vector = tfidf_transformer.transform(word_count_vector)

# %%
tf_idf_vector
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 883116 stored elements and shape (1083, 15304)>

# %%
tf_idf_vector.shape
# Out:
# (1083, 15304)

# %% [markdown]
# ### Transformation with fitted models

# %%
tfidf = pickle.load(open("C:\\Projects_by_month\\MLproject\\models\\tfidf_transformer.pkl","rb"))
cv = pickle.load(open("C:\\Projects_by_month\\MLproject\\models\\count_vectorizer_v1.pkl","rb"))

# %%
feature_names = cv.get_feature_names_out()

# %%
feature_names
# Out:
# array(['000', '000km', '000m', ..., 'отдельный', 'род', 'сухопутный'],
#       shape=(15304,), dtype=object)

# %%
def sort_coo(coo_matrix):
    
    tuples = zip(coo_matrix.col, coo_matrix.data)
    
    return sorted(tuples,key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    
    sorted_items = sorted_items[:topn]
    
    score_vals = []
    feature_vals = []
    
    for idx, score in sorted_items:
        
        score_vals.append(round(score,3))
        feature_vals.append(feature_names[idx])
        
    results = {}
    
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]] = score_vals[idx]
    
    return results


def convert_doc_to_vector(doc):
    feature_names = cv.get_feature_names_out()
    top_n = 10
    tf_idf_vector = tfidf.transform(cv.transform([doc]))
    
    sorted_items = sort_coo(tf_idf_vector.tocoo())
    
    keywords = extract_topn_from_vector(feature_names, sorted_items, top_n)
    
    return keywords

# %%
data['keywords'] = data['report_text_stemm'].apply(lambda x: convert_doc_to_vector(x))

# %%
data['keywords'][0]
# Out:
# {'twenti': np.float64(0.519),
#  'thirti': np.float64(0.271),
#  'airport': np.float64(0.241),
#  'kyiv': np.float64(0.214),
#  'hostomel': np.float64(0.192),
#  'pm': np.float64(0.175),
#  'crippl': np.float64(0.15),
#  'airlift': np.float64(0.142),
#  'chernobyl': np.float64(0.132),
#  'local': np.float64(0.13)}

# %%
data_vectorised = tf_idf_vector.toarray()

# %%
vectors_df = pd.DataFrame(data_vectorised)

# %%
vectors_df.to_csv("C:\\Projects_by_month\\MLproject\\data\\ISW_csv\\copy\\isw_vectorised.csv")
